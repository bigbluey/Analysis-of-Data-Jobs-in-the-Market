# %% [markdown]
# # Bay Area Job Listings

# %%
# Dependencies & Setup
import pandas as pd
import numpy as np
import requests
import json
from os.path import exists
import simplejson as json 

# Retrieve Google API Key from config.py
from config_3 import gkey

# %%
# File to Load
file_to_load = "data/data_analyst_sf_final.csv"

# Read Scraped Data (CSV File) & Store Into Pandas DataFrame
job_listings_df = pd.read_csv(file_to_load, encoding="ISO-8859-1")

# %%
# Drop BA NaN's
revised_job_listings_df = job_listings_df.dropna()
revised_job_listings_df.head()
# Out:
#                company                                          job_title  \
# 0                  Bey   (Permanent Job) Data Scientist Product Analytics
# 1  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 2  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 3          ProClinical          Accountant / Supplier Master Data Analyst
# 4            BlackRock                    Analyst - Index Data Operations
#
#                 location
# 0  San Francisco, CA, US
# 1  San Francisco, CA, US
# 2        Hayward, CA, US
# 3      San Mateo, CA, US
# 4   San Francisco, US-CA

# %%
# Reorganize BA File Column Names
organized_job_listings_df = revised_job_listings_df.rename(columns={"company":"Company Name", 
                                                      "job_title":"Job Title",  
                                                      "location":"Location"})
organized_job_listings_df.head()
# Out:
#           Company Name                                          Job Title  \
# 0                  Bey   (Permanent Job) Data Scientist Product Analytics
# 1  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 2  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 3          ProClinical          Accountant / Supplier Master Data Analyst
# 4            BlackRock                    Analyst - Index Data Operations
#
#                 Location
# 0  San Francisco, CA, US
# 1  San Francisco, CA, US
# 2        Hayward, CA, US
# 3      San Mateo, CA, US
# 4   San Francisco, US-CA

# %%
# Extract Only Job Titles with "Data" as String
new_organized_job_listings_df = organized_job_listings_df[organized_ba_job_listings_df["Job Title"].
                                                            str.contains("Data", case=True)]
new_organized_job_listings_df.head()
# Out:
# /Users/josephyon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#           Company Name                                          Job Title  \
# 0                  Bey   (Permanent Job) Data Scientist Product Analytics
# 1  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 2  Bechtel Corporation  2019 Student Internship (U.S.) - Big Data Anal...
# 3          ProClinical          Accountant / Supplier Master Data Analyst
# 4            BlackRock                    Analyst - Index Data Operations
#
#                 Location
# 0  San Francisco, CA, US
# 1  San Francisco, CA, US
# 2        Hayward, CA, US
# 3      San Mateo, CA, US
# 4   San Francisco, US-CA

# %%
print(len(new_organized_job_listings_df))
# Out:
# 554

# %%
new_organized_job_listings_df.dtypes
# Out:
# Company Name       object
# Job Title          object
# Location           object
# company_address    object
# dtype: object

# %%
# Extract Unique Locations
new_organized_job_listings_df["company_address"] = new_organized_job_listings_df["Company Name"] + ", " + new_organized_job_listings_df["Location"]
unique_locations = new_organized_job_listings_df["company_address"].unique().tolist()

unique_locations
# Out:
# /Users/josephyon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['Bey, San Francisco, CA, US',
#  'Bechtel Corporation, San Francisco, CA, US',
#  'Bechtel Corporation, Hayward, CA, US',
#  'ProClinical, San Mateo, CA, US',
#  'BlackRock, San Francisco, US-CA',
#  'Google, San Francisco, CA, US',
#  'Roche, South San Francisco, CA, US',
#  'Digitas North America, San Francisco, California',
#  'Genentech, South San Francisco, CA, US',
#  'RPX Corporation, One Market Plaza Steuart Tower, Suite 1100, San Francisco, CA 94105, US',
#  'Evolver, San Francisco, CA, US',
#  'Superior Court of CA, County of San Mateo, San Mateo, CA, US',
#  'Essex Property Trust, San Mateo, CA, US',
#  'Essex Corporation, San Mateo, CA, US',
#  'Armanino LLP, San Ramon, California',
#  'Impetus, San Francisco, CA, US',
#  'ARC Document Solutions, San Ramon, CA, US',
#  'Planet Pharma, South San Francisco, CA, US',
#  'InfiCare Software Technologies, San Francisco, CA, US',
#  'Asian Art Museum, 200 larkin street, san francisco, CA 94102, US',
#  'Harnham, San Francisco, CA, US',
#  'Apex Systems, San Francisco, California',
#  'Altair, San Francisco, CA, US',
#  'InfiCare Technologies, San Francisco, CA, US',
#  'Cynet Systems Inc, Foster City, CA, US',
#  'Perfict Global, Inc, San Francisco, CA, US',
#  'Clarity Insights, San Francisco, CA, US',
#  'University of California, Berkeley, Berkeley, CA, US',
#  'Silicon Valley Bank, San Francisco, CA, US',
#  'First Tek, Inc., San Ramon, CA, US',
#  'Premier Research, San Francisco, CA, US',
#  'BIND, San Francisco, CA, US',
#  'Invitae, San Francisco, CA, US',
#  'Planet Pharma, Redwood City, CA, US',
#  'Fourth Floor, San Francisco, CA, US',
#  'Dolby Laboratories, San Francisco, CA, US',
#  'Navigant, San Francisco, CA, US',
#  'Kaiser Permanente, Oakland, CA, US',
#  'Bank of the West, San Francisco, CA, US',
#  'Republic Bancorp Mortgage, San Francisco, CA, US',
#  'First Republic Bank, San Francisco, CA, US',
#  'MatchPoint Solutions, San Francisco, CA, US',
#  'KeepTruckin, San Francisco, CA, US',
#  'Dropbox, San Francisco, CA, US',
#  'Stella.ai, San Francisco, CA, US',
#  'Delta Dental of California, Oakland, CA, US',
#  'Winebow, Benicia, CA, US',
#  'iTalent Digital, San Francisco, CA, US',
#  'Citrine Informatics, Redwood City, CA, US',
#  'Mission Bio, South San Francisco, CA, US',
#  'Seasoned, San Francisco, California',
#  'Penserra, 4 Orinda Way, 100-A, Orinda, CA 94563, US',
#  'Autodesk, San Francisco, CA, US',
#  'FocusKPI, Inc., San Francisco, CA, US',
#  'Brex, San Francisco, CA, US',
#  'University of San Francisco, San Francisco, CA, US',
#  'Thistle, San Francisco, CA, US',
#  'Plum Commercial Real Estate Lending, San Francisco, CA, US',
#  'Stanza, San Francisco, CA, US',
#  '6sense, San Francisco, CA, US',
#  'Wish, San Francisco, CA, US',
#  'Crunchbase, San Francisco, CA, US',
#  'Sentry (sentry.io), San Francisco, CA, US',
#  'TrueAccord, San Francisco, CA, US',
#  'ThousandEyes, San Francisco, CA, US',
#  'Thorn, San Francisco, CA, US',
#  'University of California, San Francisco, San Francisco, CA, US',
#  'InfoSmart Technologies,Inc., South San Francisco, CA, US',
#  'Rose International, San Francisco, CA, US',
#  'Babylist, Oakland, CA, US',
#  'JiWire, San Francisco, CA, US',
#  'Cheetah, San Francisco Bay Area',
#  'Academy of Art University, San Francisco, California, United States',
#  'Simple Habit, San Francisco, CA, US',
#  'Figma, San Francisco, CA, US',
#  'Veritis Group Inc, San Francisco, CA, US',
#  'Spectraforce Technologies, San Francisco, CA, US',
#  'Vim, San Francisco, CA, US',
#  'Vinsys Information Technology Inc, San Francisco, CA, US',
#  'Cognetik, San Francisco, CA, US',
#  'Robert Half, San Francisco, CA, US',
#  'Enquero, San Francisco, CA, US',
#  'Intellipro Group Inc, San Francisco, CA, US',
#  'Creative Circle, San Francisco, CA, US',
#  'Rally Health, San Francisco, CA, US',
#  'Apex Life Sciences, San Francisco, CA, US',
#  'Nurx, San Francisco, CA, US',
#  'VelvetJobs, San Francisco, CA, US',
#  'Kelly Services, South San Francisco, CA, US',
#  'The Climate Corporation, San Francisco, CA, US',
#  'Apex Systems, San Francisco, CA, US',
#  'Spin, San Francisco, CA, US',
#  'Pocket Gems, San Francisco, CA, US',
#  'Rhumbix, San Francisco, California',
#  'Jobot, Oakland, CA, US',
#  'Upstart, San Carlos, CA, US',
#  'Eaze, San Francisco, CA, US',
#  'SHIFT.com, San Francisco, CA, US',
#  'CBRE, San Francisco, CA, US',
#  'Spin - Electric Scooter Sharing, San Francisco, CA, US',
#  'HouseCanary, San Francisco, CA, US',
#  'CalmCo, San Francisco, CA, US',
#  'The E.W. Scripps Company, San Francisco, CA, US',
#  'Rocketship Public Schools, Redwood City, CA, US',
#  'IT Avalon, San Ramon, CA, US',
#  'LumenData, San Francisco Bay Area',
#  'Atreca, Inc., Redwood City, CA, US',
#  'MW Partners, San Francisco, CA, US',
#  'Automatic, San Francisco, CA, US',
#  'AtlantiCare, San Francisco, CA, US',
#  'B-Stock Solutions, San Francisco Bay Area',
#  'Twitch, San Francisco, CA, US',
#  'Agoda, San Francisco, CA, US',
#  'Jobs @ TheJobNetwork, San Francisco, CA, US',
#  'Comscore, Inc., San Francisco, CA, US',
#  'Roblox, San Mateo, CA, US',
#  'Amplitude, San Francisco, CA, US',
#  'CyberCoders, Hayward, CA, US',
#  'BioRad, Hercules, CA, US',
#  'Fivetran, Oakland, CA, US',
#  'Old Navy, San Francisco, CA, US',
#  'Snowflake, San Mateo, CA, US',
#  'ARTECH, San Bruno, CA, US',
#  'Sensor Tower, San Francisco, CA, US',
#  'Nextdoor, San Francisco, CA, US',
#  'Construction Jobs., San Francisco, CA, US',
#  'CodeForce 360, San Francisco, CA, US',
#  'TechDigital Corporation, San Francisco, CA, US',
#  'Scoot Networks, San Francisco, CA, US',
#  'InterSources Inc - SBA Certified,Minority Owned & Women Owned Enterprise. , San Francisco, CA, US',
#  'ARTECH, San Francisco, CA, US',
#  'SGA S.A., San Francisco, CA, US',
#  'Doximity, San Francisco, CA, US',
#  'Uber, San Francisco, CA, US',
#  'Intelletec, San Mateo, CA, US',
#  'Epik Solutions, San Francisco, CA, US',
#  'Omada Health, San Francisco, CA, US',
#  'First San Francisco Partners, Oakland, CA, US',
#  'Glu Mobile, San Francisco, CA, US',
#  'Glu Mobile, San Mateo, CA, US',
#  'APN Consulting Inc., Redwood Shores, CA, US',
#  'Lumen Solutions Inc, San Ramon, CA, US',
#  'Rose IT, San Francisco, CA, US',
#  'Perficient, San Francisco, CA, US',
#  'Perficient, San Francisco, California, United States',
#  'Agency360, San Francisco, California, United States',
#  'Agency360, San Francisco, CA, US',
#  'Client Company, San Francisco, CA, US',
#  'True Botanicals, San Francisco Bay Area',
#  'Bracket, San Francisco, CA, US',
#  'Bio-Rad Laboratories, Hercules, CA, US',
#  'TalentBurst, an Inc 5000 company, San Francisco, CA, US',
#  'Abbott, Alameda, CA, US',
#  'Techshed, Foster City, CA, US',
#  'Aita Consulting Services Inc., South San Francisco, CA, US',
#  'Myriad Genetics, South San Francisco, CA, US',
#  'Lime, San Francisco, CA, US',
#  'Real Estate Exchange Inc, Redwood City, CA, US',
#  'Workato, San Francisco, CA, US',
#  'Sovereign Technologies LLC, San Francisco, CA, US',
#  'Flexport, San Francisco, CA, US',
#  'Marqeta, Inc, Oakland, CA, US',
#  'Jobs @ TheJobNetwork, Redwood City, CA, US',
#  'Atreca, Inc., Redwood City, California',
#  'Proteus Digital Health, Inc, Redwood City, CA, US',
#  'Square, San Francisco, CA, US',
#  'Planet Pharma, San Mateo, CA, US',
#  'The Athletic, San Francisco, CA, US',
#  'DASAN Zhone Solutions, Oakland, CA, US',
#  'Twitter, San Francisco, CA, US',
#  'Matrix Precise, Oakland, CA, US',
#  'Eurofins, Berkeley, CA, US',
#  'Digital Intelligence BV, Oakland, CA, US',
#  'Whistle Labs, San Francisco Bay Area',
#  'Bank of the West, San Ramon, CA, US',
#  'Fisher Investments, San Mateo, CA, US',
#  'Adobe, San Mateo, CA, US',
#  'Chartio, San Francisco, CA, US',
#  'Splunk, San Francisco, CA, US',
#  'PlushCare, San Francisco, CA, US',
#  'LaunchDarkly, Oakland, CA, US',
#  'The Darkly Agency, Oakland, CA, US',
#  'Trilogy Education, Belmont, CA, US',
#  'goPuff, San Francisco, CA, US',
#  'Energize Group, San Francisco, California',
#  'Accenture, San Francisco, CA, US',
#  'Fetch, San Francisco, California, United States',
#  'Trilogy Education, San Francisco, CA, US',
#  'Pepco Holdings, San Francisco, CA, US',
#  'Deloitte, San Francisco, CA, US',
#  'DoorDash, San Francisco, CA, US',
#  'Walmart eCommerce, San Bruno, CA, US',
#  'First Place for Youth, Oakland, CA, US',
#  'Acumen, LLC, Burlingame, CA, US',
#  'Eclaro, San Francisco, CA, US',
#  'Accela, San Ramon, CA, US',
#  'Compas, Inc., San Francisco, CA, US',
#  'Jobspring Partners, San Francisco, CA, US',
#  'Jobs @ TheJobNetwork, San Lorenzo, CA, US',
#  'Samba TV, San Francisco, CA, US',
#  'The Judge Group, San Francisco, CA, US',
#  'TechFetch.com - On Demand Tech Workforce hiring platform, San Francisco, CA, US',
#  'WeWork, San Francisco, CA, US',
#  'Persistent Systems, Foster City, California, United States',
#  'Innominds, San Francisco, CA, US',
#  'DBA Web Technologies, San Francisco, CA, US',
#  'Spectraforce Technologies, Concord, CA, US',
#  'Apex Systems, San Mateo, California',
#  'ARTECH, Redwood City, CA, US',
#  'Central Business Solutions, San Francisco, CA, US',
#  'GoodData, San Francisco, California, United States',
#  '360pi (acquired by Market Track), San Francisco, CA, US',
#  'Numerator, San Francisco, CA, US',
#  'DBA Web Technologies, San Ramon, CA, US',
#  'YouTube, San Bruno, CA, US',
#  'Gusto, San Francisco, CA, US',
#  'Zâ\x89\x88â\x84¢M Fitness, Redwood City, CA, US',
#  'ZUM, Redwood City, California',
#  'Wells Fargo, San Francisco, CA, US',
#  'Omega Solutions, Inc., San Francisco, CA, US',
#  'U.S. Bank, San Francisco, CA, US',
#  'Fremont Bank, San Francisco, CA, US',
#  'Visa, Foster City, CA, US',
#  'Franklin Energy, San Francisco, CA, US',
#  'Fitbit, San Francisco, CA, US',
#  'Instapage, San Francisco, CA, US',
#  'Synthego Corporation, Redwood City, CA, US',
#  'Walmart Labs, San Bruno, CA, US',
#  'Walmart, San Bruno, CA, US',
#  'BeiGene, Emeryville, CA, US',
#  'VSCOÂ¬Ã\x86, San Francisco, California, United States',
#  'Langan Engineering & Environmental Services, Oakland, CA, US',
#  'APN Consulting Inc., Oakland, CA, US',
#  'Cynet Systems Inc, San Francisco, CA, US',
#  'Upwork, San Francisco Bay Area',
#  'Robert Half, Foster City, CA, US',
#  'Lyft, San Francisco, CA, US',
#  'EY, San Francisco, CA, US',
#  'SAP Ariba, South San Francisco, CA, US',
#  'SAP, South San Francisco, CA, US',
#  'Automattic, San Francisco, CA, US',
#  'Quantcast, San Francisco, CA, US',
#  'Medal, San Francisco, CA, US',
#  'University of California Office of the President, Oakland, CA, US',
#  'UCSF Medical Center, San Francisco, CA, US',
#  'Robert Walters, San Francisco, California, United States',
#  'San Francisco Federal Credit Union, San Francisco, CA, US',
#  'Blue Shield of California, San Francisco, CA, US',
#  'company, location',
#  'Accelon Pty Limited, San Rafael, CA, US',
#  'Accelon Inc., San Rafael, CA, US',
#  'QuinStreet, San Francisco Bay Area',
#  'Merkle, San Francisco, CA, US',
#  'HonorVet Technologies, San Bruno, CA, US',
#  'Common Networks, San Francisco, CA, US',
#  'Oportun, San Carlos, California',
#  'Delta Dental of California, San Francisco, CA, US',
#  'Digitas North America, San Francisco Bay Area',
#  'Google, Redwood City, CA, US',
#  'PlayStation, San Mateo, CA, US',
#  'Sony Corporation of America, San Mateo, CA, US',
#  'Innovate Public Schools, San Francisco, CA, US',
#  'Axioma Inc., San Francisco, California, United States',
#  'Databricks, San Francisco, CA, US',
#  'Qualia, San Francisco, CA, US',
#  'Okta, Inc., San Francisco, CA, US',
#  'Stanford University, Redwood City, California, United States',
#  'Stryker, Fremont, CA, US',
#  'Unity Technologies, San Francisco, CA, US',
#  'Techaxis, Inc, San Francisco Bay Area',
#  'TribolaTech Inc, San Ramon, California, United States',
#  'Dodge & Cox, San Francisco, California, United States',
#  'OneWire, San Francisco, CA, US',
#  'Sutter Health, San Francisco, CA, US',
#  'Amazon Web Services (AWS), San Francisco, CA, US',
#  'UniMind Software Solutions, Inc, Oakland, CA, US',
#  'Queen Consulting, Concord, CA, US',
#  'Looker, San Francisco, CA, US',
#  'Fivestars, San Francisco, CA, US',
#  'BOLD, San Francisco, CA, US',
#  'Academia Higher Education Colleges, San Francisco, CA, US',
#  'Hipcamp, San Francisco, CA, US',
#  'Infotech Sourcing, San Francisco, CA, US',
#  'QUIP S.A., San Francisco, CA, US',
#  'Intelletec, San Francisco, CA, US',
#  'Ready State, San Francisco, CA, US',
#  'Collabera Inc., Foster City, CA, US',
#  'Zeta Global, San Francisco, CA, US',
#  'Grupo Zeta, San Francisco, CA, US',
#  'Slack, San Francisco, CA, US',
#  'Levi Strauss & Co., San Francisco, CA, US',
#  'Malakye.com, San Francisco, CA, US',
#  'US Tech Solutions, San Francisco, California, United States',
#  'LanceSoft, Inc., San Leandro, CA, US',
#  'CBRE, Oakland, CA, US',
#  'Qualys, Foster City, CA, US',
#  'GitHub, San Francisco, CA, US',
#  'Acumen Solutions, San Francisco, CA, US',
#  'Capgemini, San Francisco, CA, US',
#  'Poshmark, Redwood City, CA, US',
#  'Thrive Global, San Francisco, CA, US',
#  'Sumo Logic, Redwood City, CA, US',
#  'Guardant Health, Redwood City, CA, US',
#  'MATRIX Resources, San Francisco, CA, US',
#  'MoTek Technologies, San Francisco Bay Area',
#  'Robert Half, Oakland, CA, US',
#  'Brilliant.org, San Francisco, CA, US',
#  'Intercom, San Francisco, CA, US',
#  'Braintree, San Francisco, CA, US',
#  'Returnly, San Francisco, CA, US',
#  'Rocksbox, San Francisco, CA, US',
#  'Chime, San Francisco, CA, US',
#  'Discord, San Francisco, CA, US',
#  'ipsy, San Mateo, CA, US',
#  'NerdWallet, San Francisco Bay Area',
#  'Wikimedia Foundation, San Francisco Bay Area',
#  'Carrot Inc., Redwood City, CA, US',
#  'Superhuman, San Francisco, CA, US',
#  'Ginger, San Francisco Bay Area',
#  'Credit Sesame, San Francisco, California',
#  'QuanticMind, San Mateo, CA, US',
#  'InClassToday, San Francisco, CA, US',
#  'Credit Karma, San Francisco, CA, US',
#  'Epic! Kids, Redwood City, CA, US',
#  'Pill Club, San Carlos, CA, US',
#  'GoFundMe, Redwood City, California, United States',
#  'ASSET MARK LTD, Concord, CA, US',
#  'Glu Mobile, 875 Howard Street Suite 100, San Francisco, CA 94103, US',
#  'Eventbrite, San Francisco, CA, US',
#  'Verto Analytics, San Francisco, CA, US',
#  'Capgemini, South San Francisco, CA, US',
#  'Grand Rounds, Inc., San Francisco, CA, US',
#  'BLUE OWL, San Francisco, CA, US',
#  'Reddit, Inc., San Francisco, CA, US',
#  'Life360, San Francisco, California',
#  'The Judge Group, San Bruno, CA, US',
#  'Strava, San Francisco, California, United States',
#  'Atomic, San Francisco, CA, US',
#  'TalkIQ, San Francisco, CA, US',
#  'Sonder Inc., San Francisco, CA, US',
#  'Unison Home Ownership Investors, 650 California St, San Francisco, California 94108',
#  'Unison, San Francisco, CA, US',
#  'Unison Home Ownership Investors, San Francisco, CA, US',
#  'Sojern, San Francisco, CA, US',
#  'VelvetJobs, San Ramon, CA, US',
#  'OpenTable, San Francisco, CA, US',
#  'Truvalue Labs, San Francisco, CA, US',
#  'Insightly, San Francisco, California, United States',
#  'Workbridge Associates, San Francisco, CA, US',
#  'Ancestry, San Francisco, CA, US',
#  'DocuSign, San Francisco, CA, US',
#  'Clover Health, San Francisco, CA, US',
#  'Clarivate Analytics, San Francisco, CA, US',
#  'Wonderschool, San Francisco, CA, US',
#  'Woodruff Sawyer, San Francisco',
#  'Optimizely, San Francisco, CA, US',
#  'RevUp Software Inc., Redwood City, CA, US',
#  'RevUp Software, Redwood City, CA, US',
#  'CyberCoders, Alameda, CA, US',
#  'ServiceNow, San Francisco, CA, US',
#  'PDDN, San Francisco, CA, US',
#  'Informatica, Redwood City, CA, US',
#  'Zendesk, San Francisco, CA, US',
#  'Coupa Software, San Mateo, CA, US',
#  'AURA, s.r.o., San Francisco, CA, US',
#  'Insikt, San Francisco, CA, US',
#  '2K, Novato, CA, US',
#  'VelvetJobs, Novato, CA, US',
#  'Shutterfly, Inc., Redwood City, CA, US',
#  'GenapSys, Inc., Redwood City, CA, US',
#  'TEAM, Inc., Richmond, CA, US',
#  'FICO, San Rafael, CA, US',
#  'FICO, San Rafael, California, United States',
#  'Marketo, an Adobe Company, San Mateo, CA, US',
#  'Verily Life Sciences, South San Francisco, CA, US',
#  'Phil, Inc., San Francisco, California',
#  'Sumo Logic, Redwood City, California',
#  'Srisys Inc, San Francisco, CA, US',
#  'Natera, San Carlos, CA, US',
#  'Rakuten Intelligence, San Mateo, CA, US',
#  'Tiger Analytics, San Francisco, CA, US',
#  'Accolite, San Francisco, CA, US',
#  'Hotwire, San Francisco, CA, US',
#  'GoPro, San Mateo, CA, US',
#  'Intricately, San Francisco, CA, US',
#  'Gartner, San Francisco Bay Area',
#  'Oracle Corporation UK Ltd, Redwood City, CA, US',
#  'Juvo, San Francisco, CA, US',
#  'LinkedIn, San Francisco',
#  'Coinbase, San Francisco, CA, US',
#  'Datto, Inc., San Francisco, CA, US',
#  'Beacon Hill Staffing Group, Redwood City, California',
#  'VSCOÂ¬Ã\x86, Oakland, CA, US',
#  'Virtual Vocations, Inc., San Francisco, CA, US',
#  'Curology, San Francisco, CA, US',
#  'Catchafire, San Francisco, CA, US',
#  'Gap Inc., San Francisco, CA, US']

# %%
# Extract Only Company Names to Pass to Google Maps API to Gather GeoCoordinates
company = new_organized_job_listings_df[["Company Name"]].astype(str)
company.head()
# Out:
#           Company Name
# 0                  Bey
# 1  Bechtel Corporation
# 2  Bechtel Corporation
# 3          ProClinical
# 4            BlackRock

# %%
# What are the geocoordinates (latitude/longitude) of the Company Names?
company_list = list(company["Company Name"])

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
new_json = []

for location in company_list:
    params = {"address": location + ", San Francisco CA", "key": gkey}
    
    # Run Request
    response = requests.get(base_url, params=params)

    try: 
        # Extract lat/lng
        companies_geo = response.json()
        lat = companies_geo["results"][0]["geometry"]["location"]["lat"]
        lng = companies_geo["results"][0]["geometry"]["location"]["lng"]
        new_json.append({"company": location,"lat": lat,"lng": lng})
    except IndexError: 
        print(location)
# Out:
# SHIFT.com, San Francisco, CA, US
# Zââ¢M Fitness, Redwood City, CA, US
# VSCOÂ¬Ã, San Francisco, California, United States
# ipsy, San Mateo, CA, US
# Pill Club, San Carlos, CA, US
# VSCOÂ¬Ã, Oakland, CA, US

# %%
# What are the GeoCoordinates (Latitude/Longitude) of the Companies?
# company_list = list(unique_locations["Company Name"])

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
new_json = []

counter = 1

for location in unique_locations:
    params = {"address": location, "key": gkey}
    
    # Run Request
    response = requests.get(base_url, params=params)

    try: 
        # Extract lat/lng
        companies_geo = response.json()
        # print(companies_geo)
        lat = companies_geo["results"][0]["geometry"]["location"]["lat"]
        lng = companies_geo["results"][0]["geometry"]["location"]["lng"]
        new_json.append({"company": location,"lat": lat,"lng": lng})
        print(counter)
        counter += 1
    except IndexError:
        print(location)
