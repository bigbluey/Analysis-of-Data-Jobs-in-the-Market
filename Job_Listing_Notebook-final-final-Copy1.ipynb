# %%
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser

# %%
# !pip install splinter
# Out:
# Requirement already satisfied: splinter in /Users/josephyon/anaconda3/lib/python3.7/site-packages (0.10.0)
# Requirement already satisfied: selenium>=3.141.0 in /Users/josephyon/anaconda3/lib/python3.7/site-packages (from splinter) (3.141.0)
# Requirement already satisfied: urllib3 in /Users/josephyon/anaconda3/lib/python3.7/site-packages (from selenium>=3.141.0->splinter) (1.23)
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
html = browser.html
soup_splinter = bs(html, 'html.parser')

# %%
li_job_pages = []
def li_scraper(keyword, location, pages):
#Converting all keyword strings with spaces into url format with "%20"
    url_keyword = []
    for i in range(0, len(keyword)):
        if keyword[i] == " ":
            url_keyword.append("%20")
        else: url_keyword.append(keyword[i])
        key_string = ''.join(url_keyword)
    
#Same for location string
    url_location = []
    for i in range(0, len(location)):
        if location[i] == " ":
            url_location.append("%20")
        else: url_location.append(location[i])
        loc_string = ''.join(url_location)
#Generating url
    for i in range(0,int(pages)):
        url = f"https://www.linkedin.com/jobs/search/?keywords={key_string}&location={loc_string}%2C%20California&locationId=PLACES.us.7-1-0-38-1&start=" + str(i*25)
#Scraping url
        browser.visit(url)
        html = browser.html
        soup_splinter = bs(html, 'html.parser')
        li_job_pages.append(soup_splinter)
#These variables store their associated category of data, tags included
    job_titles = []
    for i in range(0, len(li_job_pages)):
        job_titles.append(li_job_pages[i].find_all("h3", attrs={"class": "listed-job-posting__title",
                                   }))
    job_locations = []
    for i in range(0, len(li_job_pages)):
        job_locations.append(li_job_pages[i].find_all("p", attrs={"class":"listed-job-posting__location"}))
    job_companies = []
    for i in range(0, len(li_job_pages)):
        job_companies.append(li_job_pages[i].find_all("h4", attrs={"class": "listed-job-posting__company"}))
    job_time_posted_ago = []
    for i in range(0, len(li_job_pages)):
        job_time_posted_ago.append(li_job_pages[i].find_all("span", attrs={"class":"listed-job-posting__flavor posted-time-ago__text"}))
#These variables contain the same data with tags removed.
    locations = []
    for i in range(0, len(job_locations)):
        for j in range(0, len(job_locations[i])):
            locations.append(job_locations[i][j].get_text())
    time_posted = []
    for i in range(0, len(job_time_posted_ago)):
        for j in range(0, len(job_time_posted_ago[i])):
            time_posted.append(job_time_posted_ago[i][j].get_text())
    companies = []
    for i in range(0, len(job_companies)):
        for j in range(0, len(job_time_posted_ago[i])):
            companies.append(job_companies[i][j].get_text())
    titles = []
    for i in range(0, len(job_titles)):
        for j in range(0, len(job_titles[i])):
            titles.append(job_titles[i][j].get_text())
#Return locations, time posted, compaines and job titles
    return time_posted, companies, titles, locations

# %%
job_listings = li_scraper("data scientist", "san francisco", 3)

# %%
import pandas as pd
post_data, company_name, job_title, city = job_listings
len(job_listings)
print(post_data)
print(company_name)
print(job_title)
print(city)
zippedData = list(zip(post_data, company_name, job_title, city))

job_listings = pd.DataFrame(zippedData, columns=["Post Date","Company Name","Job Title","City"]) 
job_listings
# Out:
# ['1 hour ago', '15 hours ago', '4 hours ago', '21 hours ago', '15 hours ago', '7 hours ago', '9 hours ago', '11 hours ago', '1 hour ago', '9 hours ago', '21 hours ago', '5 hours ago', '11 hours ago', '5 hours ago', '1 week ago', '7 days ago', '6 days ago', '3 hours ago', '7 hours ago', '2 hours ago', '13 hours ago', '21 hours ago', '2 weeks ago', '4 weeks ago', '1 month ago', '9 hours ago', '22 hours ago', '1 week ago', '4 weeks ago', '2 weeks ago', '2 weeks ago', '1 month ago', '3 days ago', '5 months ago', '5 days ago', '2 months ago', '15 hours ago', '2 hours ago', '6 days ago', '16 hours ago', '2 months ago', '1 day ago', '5 months ago', '6 days ago', '1 week ago', '2 days ago', '7 days ago', '2 days ago', '20 hours ago', '4 months ago', '1 week ago', '1 hour ago', '12 hours ago', '4 months ago', '14 hours ago', '1 year ago', '5 days ago', '6 days ago', '2 weeks ago', '3 weeks ago', '2 months ago', '3 months ago', '1 day ago', '3 months ago', '5 days ago', '2 days ago', '2 months ago', '4 weeks ago', '3 weeks ago', '1 month ago', '1 month ago', '1 month ago', '2 months ago', '2 months ago', '5 days ago']
# ['Twitter', 'Airbnb', 'Seasoned', 'Coinbase', 'Earnest Inc.', 'MasterClass', 'Softvision', 'Adobe', 'Walmart eCommerce', 'Intelletec', 'Bey', 'SoFi', 'Uber', 'CyberCoders', 'Personal Capital', 'Turo', 'Collabera Inc.', 'Forethought Financial Group, Inc.', '1Life Software', 'Selby Jennings', 'Wells Fargo', 'VelvetJobs', 'HONOR NYC', 'APN Consulting Inc.', 'VIZIO', 'Affirm, Inc.', 'CircleUp', "O'Reilly Media", '360pi (acquired by Market Track)', 'Wish', 'Blueshift', 'eero', 'Zignal Labs', 'Sony Playstation Network', 'Gusto', 'University of California, San Francisco', 'Formation', 'Quid', 'Pinterest', 'Roche', 'Tubi', 'Nisum', 'RiskIQ', 'Optimizely', 'Trianz', 'Wilton & Bain', 'One Medical', 'Omni Rentals', 'Pivot Bio', 'Sony Corporation of America', 'Convergent Genomics ', 'LiveRamp', 'Prezi', 'Square', 'King', 'Kanjoya, Inc', 'Smith Hanley Associates', 'BlackThorn Therapeutics', 'InfoSmart Technologies,Inc.', 'Youper', 'Juvo', 'Lime', 'Komodo Health', 'Invitae', 'Faire', 'Underdog.io', 'The RealReal', 'Numerator', 'Cynet Systems Inc', 'Jyve Corporation', 'Alt Shift', 'EDO', '6sense', 'PlayStation', 'Western Union']
# ['Data Scientist, Growth', 'Data Scientist - Analytics, Platform', 'Data Analyst', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist - 3D & Immersive', 'Data Scientist (GEC11901)', 'Director of Data Science', '(Permanent Jobs) Data Scientist (Product Analytics) and Principal Data Scientist - Salary: $150-220K', 'Director, Data Science', 'Data Scientist - Forecasting and Anomaly Detection Platform', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Head of Data Science - Consumer Lending', 'Data Scientist / Analytic Consultant 4', 'Data Scientist - Analytics, Platform', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Director - Data Science Growth', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist, Product Analytics', 'Data Scientist', 'Data Scientist - Customer Solutions', 'Applied Data Scientist', 'Data Scientist, Experimentation (Statistics)', 'Associate Data Scientist or Data Scientist, Evidence for Access, USMA', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist - Statistical Inference', 'Data Scientist', 'NLP Data Scientist', 'Data Scientist', 'Data Scientist', 'Head of Data Science', 'Data Scientist', 'Data Scientist', 'Backend/Big Data Engineer', 'Manager, Data Science & Analytics', 'Data Scientist, Operations', 'Product Data Scientist - Activision Blizzard Media', 'Data Scientist', 'Principal Data Scientist', 'Data Scientist, Neuroimaging', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist', 'Data Scientist']
# ['San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, California', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'Oakland, CA, US', 'San Francisco, CA, US', 'San Bruno, CA, US', 'San Francisco Bay Area', 'San Francisco, CA, US', 'San Francisco, CA', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, California, United States', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, California, United States', 'Oakland, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco Bay Area', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'South San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco Bay Area', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, California, United States', 'San Francisco, CA, US', 'San Francisco, CA, US', '2929 7th Street Suite 120, Berkeley, CA 94710, US', 'San Francisco, CA, US', 'San Francisco Bay Area', 'San Francisco Bay Area', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, California', 'San Francisco, California, United States', 'South San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco Bay Area', 'San Francisco, CA, US', 'San Francisco, California, United States', 'San Francisco, California, United States', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US', 'San Francisco, CA, US']
#        Post Date                       Company Name  \
# 0     1 hour ago                            Twitter
# 1   15 hours ago                             Airbnb
# 2    4 hours ago                           Seasoned
# 3   21 hours ago                           Coinbase
# 4   15 hours ago                       Earnest Inc.
# 5    7 hours ago                        MasterClass
# 6    9 hours ago                         Softvision
# 7   11 hours ago                              Adobe
# 8     1 hour ago                  Walmart eCommerce
# 9    9 hours ago                         Intelletec
# 10  21 hours ago                                Bey
# 11   5 hours ago                               SoFi
# 12  11 hours ago                               Uber
# 13   5 hours ago                        CyberCoders
# 14    1 week ago                   Personal Capital
# 15    7 days ago                               Turo
# 16    6 days ago                     Collabera Inc.
# 17   3 hours ago  Forethought Financial Group, Inc.
# 18   7 hours ago                     1Life Software
# 19   2 hours ago                     Selby Jennings
# 20  13 hours ago                        Wells Fargo
# 21  21 hours ago                         VelvetJobs
# 22   2 weeks ago                          HONOR NYC
# 23   4 weeks ago                APN Consulting Inc.
# 24   1 month ago                              VIZIO
# 25   9 hours ago                       Affirm, Inc.
# 26  22 hours ago                           CircleUp
# 27    1 week ago                     O'Reilly Media
# 28   4 weeks ago   360pi (acquired by Market Track)
# 29   2 weeks ago                               Wish
# ..           ...                                ...
# 45    2 days ago                      Wilton & Bain
# 46    7 days ago                        One Medical
# 47    2 days ago                       Omni Rentals
# 48  20 hours ago                          Pivot Bio
# 49  4 months ago        Sony Corporation of America
# 50    1 week ago               Convergent Genomics
# 51    1 hour ago                           LiveRamp
# 52  12 hours ago                              Prezi
# 53  4 months ago                             Square
# 54  14 hours ago                               King
# 55    1 year ago                       Kanjoya, Inc
# 56    5 days ago            Smith Hanley Associates
# 57    6 days ago            BlackThorn Therapeutics
# 58   2 weeks ago        InfoSmart Technologies,Inc.
# 59   3 weeks ago                             Youper
# 60  2 months ago                               Juvo
# 61  3 months ago                               Lime
# 62     1 day ago                      Komodo Health
# 63  3 months ago                            Invitae
# 64    5 days ago                              Faire
# 65    2 days ago                        Underdog.io
# 66  2 months ago                       The RealReal
# 67   4 weeks ago                          Numerator
# 68   3 weeks ago                  Cynet Systems Inc
# 69   1 month ago                   Jyve Corporation
# 70   1 month ago                          Alt Shift
# 71   1 month ago                                EDO
# 72  2 months ago                             6sense
# 73  2 months ago                        PlayStation
# 74    5 days ago                      Western Union
#
#                                             Job Title  \
# 0                              Data Scientist, Growth
# 1                Data Scientist - Analytics, Platform
# 2                                        Data Analyst
# 3                                      Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                     Data Scientist - 3D & Immersive
# 8                           Data Scientist (GEC11901)
# 9                            Director of Data Science
# 10  (Permanent Jobs) Data Scientist (Product Analy...
# 11                             Director, Data Science
# 12  Data Scientist - Forecasting and Anomaly Detec...
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                                     Data Scientist
# 16                                     Data Scientist
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19            Head of Data Science - Consumer Lending
# 20             Data Scientist / Analytic Consultant 4
# 21               Data Scientist - Analytics, Platform
# 22                                     Data Scientist
# 23                                     Data Scientist
# 24                                     Data Scientist
# 25                     Director - Data Science Growth
# 26                                     Data Scientist
# 27                                     Data Scientist
# 28                                     Data Scientist
# 29                                     Data Scientist
# ..                                                ...
# 45                                 NLP Data Scientist
# 46                                     Data Scientist
# 47                                     Data Scientist
# 48                               Head of Data Science
# 49                                     Data Scientist
# 50                                     Data Scientist
# 51                          Backend/Big Data Engineer
# 52                  Manager, Data Science & Analytics
# 53                         Data Scientist, Operations
# 54  Product Data Scientist - Activision Blizzard M...
# 55                                     Data Scientist
# 56                           Principal Data Scientist
# 57                       Data Scientist, Neuroimaging
# 58                                     Data Scientist
# 59                                     Data Scientist
# 60                                     Data Scientist
# 61                                     Data Scientist
# 62                                     Data Scientist
# 63                                     Data Scientist
# 64                                     Data Scientist
# 65                                     Data Scientist
# 66                                     Data Scientist
# 67                                     Data Scientist
# 68                                     Data Scientist
# 69                                     Data Scientist
# 70                                     Data Scientist
# 71                                     Data Scientist
# 72                                     Data Scientist
# 73                                     Data Scientist
# 74                                     Data Scientist
#
#                                                  City
# 0                               San Francisco, CA, US
# 1                               San Francisco, CA, US
# 2                           San Francisco, California
# 3                               San Francisco, CA, US
# 4                               San Francisco, CA, US
# 5                               San Francisco, CA, US
# 6                                     Oakland, CA, US
# 7                               San Francisco, CA, US
# 8                                   San Bruno, CA, US
# 9                              San Francisco Bay Area
# 10                              San Francisco, CA, US
# 11                                  San Francisco, CA
# 12                              San Francisco, CA, US
# 13                              San Francisco, CA, US
# 14                              San Francisco, CA, US
# 15                              San Francisco, CA, US
# 16                              San Francisco, CA, US
# 17                              San Francisco, CA, US
# 18                              San Francisco, CA, US
# 19           San Francisco, California, United States
# 20                              San Francisco, CA, US
# 21                              San Francisco, CA, US
# 22                              San Francisco, CA, US
# 23                              San Francisco, CA, US
# 24                              San Francisco, CA, US
# 25                              San Francisco, CA, US
# 26           San Francisco, California, United States
# 27                                    Oakland, CA, US
# 28                              San Francisco, CA, US
# 29                              San Francisco, CA, US
# ..                                                ...
# 45           San Francisco, California, United States
# 46                              San Francisco, CA, US
# 47                              San Francisco, CA, US
# 48  2929 7th Street Suite 120, Berkeley, CA 94710, US
# 49                              San Francisco, CA, US
# 50                             San Francisco Bay Area
# 51                             San Francisco Bay Area
# 52                              San Francisco, CA, US
# 53                              San Francisco, CA, US
# 54                              San Francisco, CA, US
# 55                              San Francisco, CA, US
# 56                          San Francisco, California
# 57           San Francisco, California, United States
# 58                        South San Francisco, CA, US
# 59                              San Francisco, CA, US
# 60                              San Francisco, CA, US
# 61                              San Francisco, CA, US
# 62                             San Francisco Bay Area
# 63                              San Francisco, CA, US
# 64           San Francisco, California, United States
# 65           San Francisco, California, United States
# 66                              San Francisco, CA, US
# 67                              San Francisco, CA, US
# 68                              San Francisco, CA, US
# 69                              San Francisco, CA, US
# 70                              San Francisco, CA, US
# 71                              San Francisco, CA, US
# 72                              San Francisco, CA, US
# 73                              San Francisco, CA, US
# 74                              San Francisco, CA, US
#
# [75 rows x 4 columns]

# %%
# Extract Unique Locations
job_listings["company_address"] = job_listings["Company Name"] + ", " + job_listings["City"]
unique_locations = job_listings["company_address"].unique().tolist()

print(len(unique_locations))
# Out:
# 75

# %%
# # Python SQL Toolkit and Object Relational Mapper
# import sqlalchemy
# from sqlalchemy.ext.automap import automap_base
# from sqlalchemy.orm import Session
# from sqlalchemy import create_engine, inspect, func
# from sqlalchemy.ext.declarative import declarative_base

# # Import Other Dependencies
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# # Export Pandas DataFrame to PostgreSQL
# engine = create_engine("postgresql://postgres:password@localhost:5432/job_listings_df")
# job_listings.to_sql("job_listings_df", engine)

# # Create Engine and Pass in Postgres Connection
# # Setup to Connect to Database 
# engine = create_engine("postgres://postgres:password@localhost:5432/job_listings_df")
# conn = engine.connect()

# %%
company = job_listings[["Company Name"]]
company.head()
# Out:
#    Company Name
# 0       Twitter
# 1        Airbnb
# 2      Seasoned
# 3      Coinbase
# 4  Earnest Inc.

# %%
# Dependencies
import requests
import json

# Retrieve Google API key from config.py
from config_3 import gkey

# %%
# # What are the geocoordinates (latitude/longitude) of the Company Names?
# company_list = list(company["Company Name"])
# # Build URL using the Google Maps API
# base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# for target_company in company_list:
# #     print(target_company)
#     params = {"address": target_company, "key": gkey}
# #     print(params)
# #     print("The Geocoordinates of LinkedIn Company Names")

#     # Run Request
#     response = requests.get(base_url, params=params)
# #     print(response.url)

#     # Extract lat/lng
#     companies_geo = response.json()
#     lat = companies_geo["results"][0]["geometry"]["location"]["lat"]
#     lng = companies_geo["results"][0]["geometry"]["location"]["lng"]
#     print(f"{target_company}, {lat}, {lng}")

# %%
# What are the geocoordinates (latitude/longitude) of the Company Names?
company_list = list(company["Company Name"])
# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
new_json = []
for target_company in company_list:
#     print(target_company)
    params = {"address": target_company + ", San Francisco CA", "key": gkey}
#     print(params)
#     print("The Geocoordinates of LinkedIn Company Names")

    # Run Request
    response = requests.get(base_url, params=params)
#     print(response.url)

    # Extract lat/lng
    companies_geo = response.json()
    lat = companies_geo["results"][0]["geometry"]["location"]["lat"]
    lng = companies_geo["results"][0]["geometry"]["location"]["lng"]
    new_json.append({"company":target_company,"lat":lat,"lng":lng})
#     print(f"{target_company}, {lat}, {lng}")
print(new_json)
# Out:
# [{'company': 'Twitter', 'lat': 37.7764685, 'lng': -122.4172004}, {'company': 'Airbnb', 'lat': 37.771707, 'lng': -122.4053769}, {'company': 'Seasoned', 'lat': 37.788424, 'lng': -122.405734}, {'company': 'Coinbase', 'lat': 37.7900465, 'lng': -122.4008744}, {'company': 'Earnest Inc.', 'lat': 37.7851192, 'lng': -122.3957368}, {'company': 'MasterClass', 'lat': 37.7788985, 'lng': -122.3956082}, {'company': 'Softvision', 'lat': 37.8035032, 'lng': -122.2707377}, {'company': 'Adobe', 'lat': 37.7715549, 'lng': -122.4017421}, {'company': 'Walmart eCommerce', 'lat': 37.6297459, 'lng': -122.4207288}, {'company': 'Intelletec', 'lat': 34.0879291, 'lng': -118.3446425}, {'company': 'Bey', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'SoFi', 'lat': 37.8000697, 'lng': -122.4497439}, {'company': 'Uber', 'lat': 37.7756852, 'lng': -122.4179707}, {'company': 'CyberCoders', 'lat': 40.7507617, 'lng': -73.9793758}, {'company': 'Personal Capital', 'lat': 37.5253271, 'lng': -122.2621541}, {'company': 'Turo', 'lat': 37.7871917, 'lng': -122.4005403}, {'company': 'Collabera Inc.', 'lat': 32.8735638, 'lng': -117.2150185}, {'company': 'Forethought Financial Group, Inc.', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': '1Life Software', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Selby Jennings', 'lat': 40.7527738, 'lng': -73.97418789999999}, {'company': 'Wells Fargo', 'lat': 37.7892447, 'lng': -122.4022503}, {'company': 'VelvetJobs', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'HONOR NYC', 'lat': 40.7127753, 'lng': -74.0059728}, {'company': 'APN Consulting Inc.', 'lat': 40.4169493, 'lng': -74.5269635}, {'company': 'VIZIO', 'lat': 37.7821287, 'lng': -122.4864879}, {'company': 'Affirm, Inc.', 'lat': 37.792912, 'lng': -122.405211}, {'company': 'CircleUp', 'lat': 37.7884909, 'lng': -122.404361}, {'company': "O'Reilly Media", 'lat': 38.4115223, 'lng': -122.8409299}, {'company': '360pi (acquired by Market Track)', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Wish', 'lat': 37.7713166, 'lng': -122.4144939}, {'company': 'Blueshift', 'lat': 37.7925088, 'lng': -122.4012791}, {'company': 'eero', 'lat': 37.7790354, 'lng': -122.3935863}, {'company': 'Zignal Labs', 'lat': 37.7929682, 'lng': -122.40478}, {'company': 'Sony Playstation Network', 'lat': 37.5616718, 'lng': -122.2842585}, {'company': 'Gusto', 'lat': 37.760527, 'lng': -122.384997}, {'company': 'University of California, San Francisco', 'lat': 37.7627655, 'lng': -122.457753}, {'company': 'Formation', 'lat': 37.7827507, 'lng': -122.3948099}, {'company': 'Quid', 'lat': 37.7932783, 'lng': -122.3972116}, {'company': 'Pinterest', 'lat': 37.775454, 'lng': -122.399961}, {'company': 'Roche', 'lat': 37.654189, 'lng': -122.3896475}, {'company': 'Tubi', 'lat': 37.792112, 'lng': -122.40288}, {'company': 'Nisum', 'lat': 37.7893453, 'lng': -122.3996712}, {'company': 'RiskIQ', 'lat': 37.7916003, 'lng': -122.3994343}, {'company': 'Optimizely', 'lat': 37.7861329, 'lng': -122.3988482}, {'company': 'Trianz', 'lat': 37.3870948, 'lng': -121.9668183}, {'company': 'Wilton & Bain', 'lat': 37.789836, 'lng': -122.39697}, {'company': 'One Medical', 'lat': 37.7944657, 'lng': -122.4027371}, {'company': 'Omni Rentals', 'lat': 37.7836839, 'lng': -122.4089861}, {'company': 'Pivot Bio', 'lat': 37.8517679, 'lng': -122.2909158}, {'company': 'Sony Corporation of America', 'lat': 37.7832933, 'lng': -122.3958433}, {'company': 'Convergent Genomics ', 'lat': 37.6574025, 'lng': -122.3951817}, {'company': 'LiveRamp', 'lat': 37.7908301, 'lng': -122.401286}, {'company': 'Prezi', 'lat': 37.7824195, 'lng': -122.3951131}, {'company': 'Square', 'lat': 37.775316, 'lng': -122.4174373}, {'company': 'King', 'lat': 37.7317469, 'lng': -122.451027}, {'company': 'Kanjoya, Inc', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Smith Hanley Associates', 'lat': 41.881252, 'lng': -87.639118}, {'company': 'BlackThorn Therapeutics', 'lat': 37.7735784, 'lng': -122.4031182}, {'company': 'InfoSmart Technologies,Inc.', 'lat': 33.09053 ...

# %%
# What are the geocoordinates (latitude/longitude) of the Company Names?
company_list = list(company["Company Name"])
# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

for target_company in company_list:
#     print(target_company)
    params = {"address": target_company + ", San Francisco CA", "key": gkey}
#     print(params)
#     print("The Geocoordinates of LinkedIn Company Names")

    # Run Request
    response = requests.get(base_url, params=params)
#     print(response.url)

    # Extract lat/lng
    companies_geo = response.json()
    lat = companies_geo["results"][0]["geometry"]["location"]["lat"]
    lng = companies_geo["results"][0]["geometry"]["location"]["lng"]
    new_json.append({"company":target_company,"lat":lat,"lng":lng})
    places = f"{target_company}, {lat}, {lng}"
    print(places)
# Out:
# Twitter, 37.7764685, -122.4172004
# Airbnb, 37.771707, -122.4053769
# Seasoned, 37.788424, -122.405734
# Coinbase, 37.7900465, -122.4008744
# Earnest Inc., 37.7851192, -122.3957368
# MasterClass, 37.7788985, -122.3956082
# Softvision, 37.8035032, -122.2707377
# Adobe, 37.7715549, -122.4017421
# Walmart eCommerce, 37.6297459, -122.4207288
# Intelletec, 34.0879291, -118.3446425
# Bey, 32.8297261, -117.1385718
# SoFi, 37.8000697, -122.4497439
# Uber, 37.7756852, -122.4179707
# CyberCoders, 40.7507617, -73.9793758
# Personal Capital, 37.5253271, -122.2621541
# Turo, 37.7871917, -122.4005403
# Collabera Inc., 32.8735638, -117.2150185
# Forethought Financial Group, Inc., 37.7749295, -122.4194155
# 1Life Software, 37.7911148, -122.4021273
# Selby Jennings, 40.7527738, -73.97418789999999
# Wells Fargo, 37.7892447, -122.4022503
# VelvetJobs, 37.7749295, -122.4194155
# HONOR NYC, 40.7127753, -74.0059728
# APN Consulting Inc., 40.4169493, -74.5269635
# VIZIO, 37.7749295, -122.4194155
# Affirm, Inc., 37.792912, -122.405211
# CircleUp, 37.7884909, -122.404361
# O'Reilly Media, 38.4115223, -122.8409299
# 360pi (acquired by Market Track), 37.7749295, -122.4194155
# Wish, 37.7713166, -122.4144939
# Blueshift, 37.7925088, -122.4012791
# eero, 37.7790354, -122.3935863
# Zignal Labs, 37.7929682, -122.40478
# Sony Playstation Network, 37.5616718, -122.2842585
# Gusto, 37.760527, -122.384997
# University of California, San Francisco, 37.7627655, -122.457753
# Formation, 37.7827507, -122.3948099
# Quid, 37.7932783, -122.3972116
# Pinterest, 37.775454, -122.399961
# Roche, 37.654189, -122.3896475
# Tubi, 37.792112, -122.40288
# Nisum, 37.7893453, -122.3996712
# RiskIQ, 37.7916003, -122.3994343
# Optimizely, 37.7861329, -122.3988482
# Trianz, 37.3870948, -121.9668183
# Wilton & Bain, 37.789836, -122.39697
# One Medical, 37.7944657, -122.4027371
# Omni Rentals, 37.7836839, -122.4089861
# Pivot Bio, 37.8517679, -122.2909158
# Sony Corporation of America, 37.7832933, -122.3958433
# Convergent Genomics , 37.6574025, -122.3951817
# LiveRamp, 37.7908301, -122.401286
# Prezi, 37.7824195, -122.3951131
# Square, 37.775316, -122.4174373
# King, 37.7317469, -122.451027
# Kanjoya, Inc, 37.7749295, -122.4194155
# Smith Hanley Associates, 41.881252, -87.639118
# BlackThorn Therapeutics, 37.7735784, -122.4031182
# InfoSmart Technologies,Inc., 33.0905315, -96.8356766
# Youper, 37.792115, -122.403005
# Juvo, 37.792085, -122.399368
# Lime, 37.7860026, -122.4351187
# Komodo Health, 37.7847556, -122.3993783
# Invitae, 37.7668295, -122.4013094
# Faire, 37.76638579999999, -122.4671782
# Underdog.io, 37.7636886, -122.4776562
# The RealReal, 37.8053739, -122.405593
# Numerator, 37.7749295, -122.4194155
# Cynet Systems Inc, 37.7749295, -122.4194155
# Jyve Corporation, 37.797421, -122.4047381
# Alt Shift, 37.7749295, -122.4194155
# EDO, 37.7717866, -122.4322117
# 6sense, 37.7783837, -122.3941886
# PlayStation, 37.764142, -122.4705044
# Western Union, 37.7937113, -122.4077

# %%
# !pip install simplejson
# Out:
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/e3/24/c35fb1c1c315fc0fffe61ea00d3f88e85469004713dab488dee4f35b0aff/simplejson-3.16.0.tar.gz (81kB)
#     100% |████████████████████████████████| 81kB 2.8MB/s ta 0:00:011
# Building wheels for collected packages: simplejson
#   Building wheel for simplejson (setup.py) ... done
#   Stored in directory: /Users/josephyon/Library/Caches/pip/wheels/5d/1a/1e/0350bb3df3e74215cd91325344cc86c2c691f5306eb4d22c77
# Successfully built simplejson
# Installing collected packages: simplejson
# Successfully installed simplejson-3.16.0
# You are using pip version 19.0.3, however version 19.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sys import argv
from os.path import exists
import simplejson as json 


geojson = {
    "type": "FeatureCollection",
    "features": [
    {
        "type": "Feature",
        "company": d["company"],
        "geometry" : {
            "type": "Point",
            "coordinates": [d["lat"], d["lng"]],
            },
     } for d in new_json]
}

print(geojson)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'company': 'Twitter', 'geometry': {'type': 'Point', 'coordinates': [37.7764685, -122.4172004]}}, {'type': 'Feature', 'company': 'Airbnb', 'geometry': {'type': 'Point', 'coordinates': [37.771707, -122.4053769]}}, {'type': 'Feature', 'company': 'Seasoned', 'geometry': {'type': 'Point', 'coordinates': [37.788424, -122.405734]}}, {'type': 'Feature', 'company': 'Coinbase', 'geometry': {'type': 'Point', 'coordinates': [37.7900465, -122.4008744]}}, {'type': 'Feature', 'company': 'Earnest Inc.', 'geometry': {'type': 'Point', 'coordinates': [37.7851192, -122.3957368]}}, {'type': 'Feature', 'company': 'MasterClass', 'geometry': {'type': 'Point', 'coordinates': [37.7788985, -122.3956082]}}, {'type': 'Feature', 'company': 'Softvision', 'geometry': {'type': 'Point', 'coordinates': [37.8035032, -122.2707377]}}, {'type': 'Feature', 'company': 'Adobe', 'geometry': {'type': 'Point', 'coordinates': [37.7715549, -122.4017421]}}, {'type': 'Feature', 'company': 'Walmart eCommerce', 'geometry': {'type': 'Point', 'coordinates': [37.6297459, -122.4207288]}}, {'type': 'Feature', 'company': 'Intelletec', 'geometry': {'type': 'Point', 'coordinates': [34.0879291, -118.3446425]}}, {'type': 'Feature', 'company': 'Bey', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': 'SoFi', 'geometry': {'type': 'Point', 'coordinates': [37.8000697, -122.4497439]}}, {'type': 'Feature', 'company': 'Uber', 'geometry': {'type': 'Point', 'coordinates': [37.7756852, -122.4179707]}}, {'type': 'Feature', 'company': 'CyberCoders', 'geometry': {'type': 'Point', 'coordinates': [40.7507617, -73.9793758]}}, {'type': 'Feature', 'company': 'Personal Capital', 'geometry': {'type': 'Point', 'coordinates': [37.5253271, -122.2621541]}}, {'type': 'Feature', 'company': 'Turo', 'geometry': {'type': 'Point', 'coordinates': [37.7871917, -122.4005403]}}, {'type': 'Feature', 'company': 'Collabera Inc.', 'geometry': {'type': 'Point', 'coordinates': [32.8735638, -117.2150185]}}, {'type': 'Feature', 'company': 'Forethought Financial Group, Inc.', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': '1Life Software', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': 'Selby Jennings', 'geometry': {'type': 'Point', 'coordinates': [40.7527738, -73.97418789999999]}}, {'type': 'Feature', 'company': 'Wells Fargo', 'geometry': {'type': 'Point', 'coordinates': [37.7892447, -122.4022503]}}, {'type': 'Feature', 'company': 'VelvetJobs', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': 'HONOR NYC', 'geometry': {'type': 'Point', 'coordinates': [40.7127753, -74.0059728]}}, {'type': 'Feature', 'company': 'APN Consulting Inc.', 'geometry': {'type': 'Point', 'coordinates': [40.4169493, -74.5269635]}}, {'type': 'Feature', 'company': 'VIZIO', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': 'Affirm, Inc.', 'geometry': {'type': 'Point', 'coordinates': [37.792912, -122.405211]}}, {'type': 'Feature', 'company': 'CircleUp', 'geometry': {'type': 'Point', 'coordinates': [37.7884909, -122.404361]}}, {'type': 'Feature', 'company': "O'Reilly Media", 'geometry': {'type': 'Point', 'coordinates': [38.4115223, -122.8409299]}}, {'type': 'Feature', 'company': '360pi (acquired by Market Track)', 'geometry': {'type': 'Point', 'coordinates': [37.7749295, -122.4194155]}}, {'type': 'Feature', 'company': 'Wish', 'geometry': {'type': 'Point', 'coordinates': [37.7713166, -122.4144939]}}, {'type': 'Feature', 'company': 'Blueshift', 'geometry': {'type': 'Point', 'coordinates': [37.7925088, -122.4012791]}}, {'type': 'Feature', 'company': 'eero', 'geometry': {'type': 'Point', 'coordinates': [37.7790354, -122.3935863]}}, {'type': 'Feature', 'company': 'Zignal Labs', 'geometry': {'type': 'Point', 'coordinates': [ ...

# %%
# # JSON-ify response
# response_json = new_json.json()
# response_json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-f3964ce02dc5> in <module>()
#       1 # JSON-ify response
# ----> 2 response_json = new_json.json()
#       3 response_json
#
# AttributeError: 'list' object has no attribute 'json'

# %%
# # convert response to json
# new_json = response.json()

# # Print the json (pretty printed)
# print(json.dumps(new_json, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "B",
#                     "short_name": "B",
#                     "types": [
#                         "subpremise"
#                     ]
#                 },
#                 {
#                     "long_name": "832",
#                     "short_name": "832",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Stockton Street",
#                     "short_name": "Stockton St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Chinatown",
#                     "short_name": "Chinatown",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Francisco",
#                     "short_name": "SF",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Francisco County",
#                     "short_name": "San Francisco County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "94108",
#                     "short_name": "94108",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "832 Stockton St B, San Francisco, CA 94108, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 37.7937113,
#                     "lng": -122.4077
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.7950602802915,
#                         "lng": -122.4063510197085
#                     },
#                     "southwest": {
#                         "lat": 37.7923623197085,
#                         "lng": -122.4090489802915
#                     }
#                 }
#             },
#             "place_id": "ChIJ5X_ZvIyAhYARipZ5a_oO114",
#             "plus_code": {
#                 "compound_code": "QHVR+FW Chinatown, San Francisco, CA, United States",
#                 "global_code": "849VQHVR+FW"
#             },
#             "types": [
#                 "establishment",
#                 "finance",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
print(new_json)
# Out:
# [{'company': 'Twitter', 'lat': 37.7764685, 'lng': -122.4172004}, {'company': 'Airbnb', 'lat': 37.771707, 'lng': -122.4053769}, {'company': 'Seasoned', 'lat': 37.788424, 'lng': -122.405734}, {'company': 'Coinbase', 'lat': 37.7900465, 'lng': -122.4008744}, {'company': 'Earnest Inc.', 'lat': 37.7851192, 'lng': -122.3957368}, {'company': 'MasterClass', 'lat': 37.7788985, 'lng': -122.3956082}, {'company': 'Softvision', 'lat': 37.8035032, 'lng': -122.2707377}, {'company': 'Adobe', 'lat': 37.7715549, 'lng': -122.4017421}, {'company': 'Walmart eCommerce', 'lat': 37.6297459, 'lng': -122.4207288}, {'company': 'Intelletec', 'lat': 34.0879291, 'lng': -118.3446425}, {'company': 'Bey', 'lat': 32.8297261, 'lng': -117.1385718}, {'company': 'SoFi', 'lat': 37.8000697, 'lng': -122.4497439}, {'company': 'Uber', 'lat': 37.7756852, 'lng': -122.4179707}, {'company': 'CyberCoders', 'lat': 40.7507617, 'lng': -73.9793758}, {'company': 'Personal Capital', 'lat': 37.5253271, 'lng': -122.2621541}, {'company': 'Turo', 'lat': 37.7871917, 'lng': -122.4005403}, {'company': 'Collabera Inc.', 'lat': 32.8735638, 'lng': -117.2150185}, {'company': 'Forethought Financial Group, Inc.', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': '1Life Software', 'lat': 37.7911148, 'lng': -122.4021273}, {'company': 'Selby Jennings', 'lat': 40.7527738, 'lng': -73.97418789999999}, {'company': 'Wells Fargo', 'lat': 37.7892447, 'lng': -122.4022503}, {'company': 'VelvetJobs', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'HONOR NYC', 'lat': 40.7127753, 'lng': -74.0059728}, {'company': 'APN Consulting Inc.', 'lat': 40.4169493, 'lng': -74.5269635}, {'company': 'VIZIO', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Affirm, Inc.', 'lat': 37.792912, 'lng': -122.405211}, {'company': 'CircleUp', 'lat': 37.7884909, 'lng': -122.404361}, {'company': "O'Reilly Media", 'lat': 38.4115223, 'lng': -122.8409299}, {'company': '360pi (acquired by Market Track)', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Wish', 'lat': 37.7713166, 'lng': -122.4144939}, {'company': 'Blueshift', 'lat': 37.7925088, 'lng': -122.4012791}, {'company': 'eero', 'lat': 37.7790354, 'lng': -122.3935863}, {'company': 'Zignal Labs', 'lat': 37.7929682, 'lng': -122.40478}, {'company': 'Sony Playstation Network', 'lat': 37.5616718, 'lng': -122.2842585}, {'company': 'Gusto', 'lat': 37.760527, 'lng': -122.384997}, {'company': 'University of California, San Francisco', 'lat': 37.7627655, 'lng': -122.457753}, {'company': 'Formation', 'lat': 37.7827507, 'lng': -122.3948099}, {'company': 'Quid', 'lat': 37.7932783, 'lng': -122.3972116}, {'company': 'Pinterest', 'lat': 37.775454, 'lng': -122.399961}, {'company': 'Roche', 'lat': 37.654189, 'lng': -122.3896475}, {'company': 'Tubi', 'lat': 37.792112, 'lng': -122.40288}, {'company': 'Nisum', 'lat': 37.7893453, 'lng': -122.3996712}, {'company': 'RiskIQ', 'lat': 37.7916003, 'lng': -122.3994343}, {'company': 'Optimizely', 'lat': 37.7861329, 'lng': -122.3988482}, {'company': 'Trianz', 'lat': 37.3870948, 'lng': -121.9668183}, {'company': 'Wilton & Bain', 'lat': 37.789836, 'lng': -122.39697}, {'company': 'One Medical', 'lat': 37.7944657, 'lng': -122.4027371}, {'company': 'Omni Rentals', 'lat': 37.7836839, 'lng': -122.4089861}, {'company': 'Pivot Bio', 'lat': 37.8517679, 'lng': -122.2909158}, {'company': 'Sony Corporation of America', 'lat': 37.7832933, 'lng': -122.3958433}, {'company': 'Convergent Genomics ', 'lat': 37.6574025, 'lng': -122.3951817}, {'company': 'LiveRamp', 'lat': 37.7908301, 'lng': -122.401286}, {'company': 'Prezi', 'lat': 37.7824195, 'lng': -122.3951131}, {'company': 'Square', 'lat': 37.775316, 'lng': -122.4174373}, {'company': 'King', 'lat': 37.7317469, 'lng': -122.451027}, {'company': 'Kanjoya, Inc', 'lat': 37.7749295, 'lng': -122.4194155}, {'company': 'Smith Hanley Associates', 'lat': 41.881252, 'lng': -87.639118}, {'company': 'BlackThorn Therapeutics', 'lat': 37.7735784, 'lng': -122.4031182}, {'company': 'InfoSmart Technologies,Inc.', 'lat': 33.09053 ...
